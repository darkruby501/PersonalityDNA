# %%
#Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Set figure aesthetics
sns.set_style("white", {'ytick.major.size': 8.0})
sns.set_context("poster", font_scale=1.0)

# %%
#Load file

df = pd.read_csv('data/sapaTempData696items08dec2013thru26jul2014.csv')
df.drop(df.columns[0],1,inplace=True)
df.head()
# Out:
#           RID  gender     relstatus  age      marstatus  height    BMI  \
# 0  2138157442  female     committed   39  domesticPrtnr      64  21.11
# 1  1768368569  female  notCommitted   62  domesticPrtnr      63  19.13
# 2    59911536  female  notCommitted   18   neverMarried      60  22.07
# 3   208724670    male  notCommitted   21   neverMarried      73  23.48
# 4  2121514443  female     committed   22   neverMarried      65  19.63
#
#    weight     exer    smoke  ...   q_4291 q_4292 q_4293  q_4294 q_4295 q_4296  \
# 0     123  more5wk    never  ...        1    NaN    NaN     NaN    NaN    NaN
# 1     108   1or2wk    never  ...      NaN    NaN    NaN     NaN      1    NaN
# 2     113  more5wk  less1mo  ...      NaN    NaN    NaN       5    NaN    NaN
# 3     178  less1wk  less1mo  ...      NaN    NaN    NaN     NaN    NaN      3
# 4     118  more5wk    never  ...      NaN    NaN      1     NaN    NaN    NaN
#
#   q_4297 q_4298 q_4299 q_4300
# 0    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN
# 2    NaN      4      5      1
# 3    NaN      6    NaN    NaN
# 4    NaN      5      6    NaN
#
# [5 rows x 716 columns]

# %%
X.replace({1:-3,2:-2,3:-1,4:1,5:2,6:3},inplace=True)

# %%
responses.head()
# Out:
#    q_6  q_20  q_22  q_23  q_26  q_31  q_35  q_38  q_39  q_40   ...    q_4291  \
# 0  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...        -3
# 1  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...       NaN
# 2  NaN     2   NaN   NaN   NaN    -1     1   NaN   NaN   NaN   ...       NaN
# 3  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   ...       NaN
# 4  NaN     1   NaN     1   NaN   NaN   NaN   NaN   NaN   NaN   ...       NaN
#
#    q_4292  q_4293  q_4294  q_4295  q_4296  q_4297  q_4298  q_4299  q_4300
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN      -3     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN       2     NaN     NaN     NaN       1       2      -3
# 3     NaN     NaN     NaN     NaN      -1     NaN       3     NaN     NaN
# 4     NaN      -3     NaN     NaN     NaN     NaN       2       3     NaN
#
# [5 rows x 696 columns]

# %%
X = df.drop(df.columns[0:20],1)
X.replace({1:-3,2:-2,3:-1,4:1,5:2,6:3},inplace=True)

XScaled = (X-X.mean(axis=0))/X.std(axis=0) #Pandas handles all these operations in a missing aware away.

#Quick Check
XScaled.describe()

# Now fill with zeroes
XScaled.fillna(0,inplace=True)
# Out:
#                 q_6          q_20          q_22          q_23          q_26  \
# count  2.514000e+03  2.441000e+03  2.713000e+03  3.605000e+03  2.311000e+03
# mean   5.774573e-16 -1.592517e-15 -1.145825e-18 -1.176436e-17 -3.250441e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.664745e+00 -2.428978e+00 -1.740031e+00 -1.453175e+00 -1.106387e+00
# 25%   -6.043998e-01 -4.732092e-02 -6.791985e-01 -9.687836e-01 -5.464089e-01
# 50%    1.606864e-01  5.480933e-01  3.816337e-01  4.843918e-01 -5.464089e-01
# 75%    9.257726e-01  5.480933e-01  9.120498e-01  9.687836e-01  1.133526e+00
# max    9.257726e-01  1.143508e+00  1.442466e+00  1.453175e+00  2.253482e+00
#
#                q_31          q_35          q_38          q_39          q_40  \
# count  2.476000e+03  2.431000e+03  2.468000e+03  2.529000e+03  5.998000e+03
# mean  -2.304744e-17  1.333546e-17  1.771498e-16  1.101882e-16  5.824839e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.174681e+00 -1.229617e+00 -2.557124e+00 -2.698717e+00 -1.234067e+00
# 25%   -6.655770e-01 -6.951636e-01 -1.072086e-01 -1.360379e-01 -1.234067e+00
# 50%   -1.564733e-01 -1.607099e-01  5.052702e-01  5.046320e-01 -3.137717e-01
# 75%    8.617341e-01  9.081976e-01  5.052702e-01  5.046320e-01  1.066670e+00
# max    1.879941e+00  1.977105e+00  1.117749e+00  1.145302e+00  1.526818e+00
#
#            ...             q_4291        q_4292        q_4293        q_4294  \
# count      ...       2.434000e+03  2.512000e+03  2.437000e+03  2.444000e+03
# mean       ...       1.019544e-15  1.506226e-16 -3.665057e-16 -3.843080e-17
# std        ...       1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min        ...      -1.284816e+00 -1.787331e+00 -7.748785e-01 -2.288526e+00
# 25%        ...      -7.185941e-01 -7.269213e-01 -7.748785e-01 -8.757860e-02
# 50%        ...      -1.523727e-01  3.334889e-01 -1.970392e-01  4.626582e-01
# 75%        ...       9.800702e-01  8.636940e-01  3.808001e-01  1.012895e+00
# max        ...       2.112513e+00  1.393899e+00  2.692157e+00  1.012895e+00
#
#              q_4295        q_4296        q_4297        q_4298        q_4299  \
# count  2.504000e+03  2.491000e+03  2.469000e+03  2.494000e+03  2.430000e+03
# mean   1.124189e-15 -9.564587e-17  5.112692e-17 -8.849733e-17  2.266134e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.968269e+00 -7.994984e-01 -2.611582e+00 -2.635505e+00 -3.296744e+00
# 25%   -8.893404e-01 -7.994984e-01 -2.364109e-01 -1.438638e-01 -4.606284e-03
# 50%    1.895881e-01 -2.135759e-01  3.573820e-01  4.790466e-01  6.538214e-01
# 75%    7.290523e-01  3.723466e-01  9.511749e-01  4.790466e-01  6.538214e-01
# max    1.268517e+00  2.716036e+00  9.511749e-01  1.101957e+00  6.538214e-01
#
#              q_4300
# count  2.522000e+03
# mean  -5.084487e-18
# std    1.000000e+00
# min   -1.271753e+00
# 25%   -7.856419e-01
# 50%   -2.995308e-01
# 75%    6.726914e-01
# max    1.644914e+00
#
# [8 rows x 696 columns]

# %%
XScaled.fillna(0,inplace=True)

# %%
# Out:
#    q_6      q_20  q_22      q_23  q_26      q_31      q_35  q_38  q_39  \
# 0    0  0.000000     0  0.000000     0  0.000000  0.000000     0     0
# 1    0  0.000000     0  0.000000     0  0.000000  0.000000     0     0
# 2    0  0.548093     0  0.000000     0 -0.156473  0.908198     0     0
# 3    0  0.000000     0  0.000000     0  0.000000  0.000000     0     0
# 4    0 -0.047321     0  0.484392     0  0.000000  0.000000     0     0
#
#        q_40    ...       q_4291  q_4292    q_4293    q_4294    q_4295  \
# 0  0.000000    ...    -1.284816       0  0.000000  0.000000  0.000000
# 1  0.000000    ...     0.000000       0  0.000000  0.000000 -1.968269
# 2  0.000000    ...     0.000000       0  0.000000  0.462658  0.000000
# 3  0.606523    ...     0.000000       0  0.000000  0.000000  0.000000
# 4  0.000000    ...     0.000000       0 -0.774879  0.000000  0.000000
#
#      q_4296  q_4297    q_4298    q_4299    q_4300
# 0  0.000000       0  0.000000  0.000000  0.000000
# 1  0.000000       0  0.000000  0.000000  0.000000
# 2  0.000000       0 -0.143864 -0.004606 -1.271753
# 3  0.372347       0  1.101957  0.000000  0.000000
# 4  0.000000       0  0.479047  0.653821  0.000000
#
# [5 rows x 696 columns]

# %%
K = pd.DataFrame(np.dot(XScaled,XScaled.T))

# %%
K.head()
# Out:
#        0          1           2          3           4         5      \
# 0  55.708727  -1.246831    5.877986  -0.472050    3.198519 -2.666195
# 1  -1.246831  20.729468    1.263574   1.958152    1.208751 -0.054481
# 2   5.877986   1.263574  204.094899 -11.040203    0.529748  4.508743
# 3  -0.472050   1.958152  -11.040203  55.116301   -2.347335 -0.714981
# 4   3.198519   1.208751    0.529748  -2.347335  135.249653 -3.787770
#
#       6         7         8         9        ...        23671     23672  \
# 0  0.207269  4.889787  0.950767  0.502552    ...    -1.259209  3.283962
# 1 -0.465812  0.000000 -0.908655  0.127878    ...    -0.576315 -0.574117
# 2 -1.976213 -0.651868  8.887891 -4.571305    ...     4.521303  1.226088
# 3  2.318283  1.484468 -2.226736  0.790493    ...    -2.967225 -2.595084
# 4 -0.951114  0.089734 -1.582501 -2.738065    ...     1.534184  2.993237
#
#       23673     23674     23675     23676     23677      23678     23679  \
# 0 -1.126320  3.087426  1.880846  1.292083  2.311267   7.955126 -0.868219
# 1 -0.117746 -0.071767 -0.141995 -0.262295  1.779408  -1.179169 -1.642289
# 2  8.465668 -1.313090  0.402183 -6.482628 -0.042106  12.571872  0.172131
# 3 -2.961153 -0.169721 -2.464595 -4.862016  0.813390  -2.402186  5.332492
# 4  2.246280 -1.740127  6.889988 -2.874550  0.369845  -8.819770 -5.682655
#
#       23680
# 0 -4.728738
# 1  0.000000
# 2  8.700027
# 3  2.800916
# 4 -4.780504
#
# [5 rows x 23681 columns]

# %%
#KPlot = K.values[0:100,0:300]
n = 100 # number of people to compare in plot
KPlot = K.values[0:n,0:n]
np.fill_diagonal(KPlot,0)
fig = plt.figure(figsize=(10,10))  # figure size in inches
plt.imshow(KPlot,cmap=plt.cm.inferno_r)
plt.colorbar()

# %%
X = df.drop(df.columns[0:20],1)

# %%
X.iloc[3]
# Out:
# q_6      NaN
# q_20     NaN
# q_22     NaN
# q_23     NaN
# q_26     NaN
# q_31     NaN
# q_35     NaN
# q_38     NaN
# q_39     NaN
# q_40       4
# q_43     NaN
# q_44       2
# q_45     NaN
# q_47     NaN
# q_52     NaN
# q_53     NaN
# q_55     NaN
# q_56     NaN
# q_63     NaN
# q_66     NaN
# q_67     NaN
# q_69     NaN
# q_71       5
# q_74     NaN
# q_76     NaN
# q_77       4
# q_79       3
# q_80     NaN
# q_82     NaN
# q_85     NaN
#           ..
# q_4271   NaN
# q_4272   NaN
# q_4273   NaN
# q_4274   NaN
# q_4275   NaN
# q_4276   NaN
# q_4277   NaN
# q_4278   NaN
# q_4279   NaN
# q_4280   NaN
# q_4281   NaN
# q_4282     6
# q_4283   NaN
# q_4284   NaN
# q_4285   NaN
# q_4286   NaN
# q_4287   NaN
# q_4288   NaN
# q_4289   NaN
# q_4290   NaN
# q_4291   NaN
# q_4292   NaN
# q_4293   NaN
# q_4294   NaN
# q_4295   NaN
# q_4296     3
# q_4297   NaN
# q_4298     6
# q_4299   NaN
# q_4300   NaN
# Name: 3, dtype: float64

# %% [markdown]
# ## Showing that Pandas Handles Missing Aware Opertaions Correctly

# %%
a = np.array([np.nan, np.nan, 3, 3, 3])
a.mean?

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=[[np.nan, np.nan, 3],[3,3,3],[5,5,6]],columns=['A','B','C'])
df
# Out:
#     A   B  C
# 0 NaN NaN  3
# 1   3   3  3
# 2   5   5  6

# %%
df.mean()
# Out:
# A    4
# B    4
# C    4
# dtype: float64

# %%
df0 = df.fillna(0)

# %%
np.dot(df0.T,df0)
# Out:
# array([[ 34.,  34.,  39.],
#        [ 34.,  34.,  39.],
#        [ 39.,  39.,  54.]])
